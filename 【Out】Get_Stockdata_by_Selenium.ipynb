# %% [markdown]
# ### 1983年〜2019年の上場全株式の日足データをCSV形式で保存する
#
# #### 雛形URL https://www.kbm360.com/?p=278
#
# - seleniumモジュールを使用するのでcondaにてインストール
#   ```
#   conda install -c conda-forge selenium
#   conda install -c conda-forge python-chromedriver-binary
#   ```
# - chromeドライバーをインストール（ここでは/Users/KojiroT/github/Stock_Data/chromedriver）してから使用する
# - スクレイピングはサーバーに負荷をかけるのでDL間隔を3秒ごとに設定
# - 膨大なファイルの量になるのでHDDの空きスペースは十分に確保すること
#
# #### seleniumとwebdriverの環境構築
#
# - Selenium ChromeDriver & PythonをMacで動かせた<br>
# https://qiita.com/w5966qzh/items/4c1164bd7c611820c187
#
# - chromedriver パスの解決方法<br>
# https://reskyskateboard.com/python-selenium-webdriver/
#
# - SeleniumのChrome driverのデフォルトダウンロードフォルダを設定する<br>
# https://qiita.com/hikoalpha/items/fa8330391823aea2fbca
#
# - Anaconda3 + Selenium +ChromeDriver + BeautifulSoupでスクレイピング<br>
# https://qiita.com/DaisukePhoto/items/27cd0b95aee8769580b5

# %%
# ライブラリインポート
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

# %%
# webdriverのpathを設定
#driver = webdriver.Chrome('/Users/KojiroT/github/Stock_Data/chromedriver')
#path = "/Users/KojiroT/github/Stock_Data/"    # csv保存先を指定

# seleniumのDLフォルダを指定
chromeOptions = webdriver.ChromeOptions()
prefs = {"download.default_directory" : "/Users/KojiroT/github/Stock_Data/"}
chromeOptions.add_experimental_option("prefs",prefs)
#Chrome diriverのパス
driver = webdriver.Chrome(executable_path='/Users/KojiroT/github/Stock_Data/chromedriver', chrome_options=chromeOptions)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: use options instead of chrome_options
#   # Remove the CWD from sys.path while we load stuff.

# %%
def download_stock_csv(code_range,year_range):
    for code in code_range:
        try:
            for year in year_range:
                url = 'https://kabuoji3.com/stock/{0}/{1}/'.format(code,year)
                driver.get(url)
 
                try:
                    driver.find_element_by_name("csv").click()
                    time.sleep(3)
                    driver.find_element_by_name("csv").click()
                except NoSuchElementException:
                    print("no data")
                    pass
                time.sleep(1)
 
        except NoSuchElementException:
            print("no data")
        pass
    time.sleep(1)

download_stock_csv(range(1399,9998),range(2017,2020))
# Out:
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# no data
# ...
